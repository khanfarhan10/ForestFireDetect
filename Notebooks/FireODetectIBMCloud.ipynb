# %%
# !pip install pyarrow 
# !pip install sqlparse

# %%
#!pip install --upgrade --user  ibmcloudsql
#!pip install ibmcloudsql
# !pip install --upgrade --global  ibmcloudsql
# Out:
# /usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.12.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# arviz                         0.11.2
# astor                         0.8.1
# astropy                       4.2.1
# astunparse                    1.6.3
# async-generator               1.10
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.2.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# backoff                       1.10.0
# beautifulsoup4                4.6.3
# bleach                        3.3.0
# blis                          0.4.1
# bokeh                         2.3.2
# ...

# %%
import ibmcloudsql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-4fc28aa5c714> in <module>()
# ----> 1 import ibmcloudsql
#
# ModuleNotFoundError: No module named 'ibmcloudsql'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import sqlparse 
import pandas as pd
import getpass
import pprint
from pygments import highlight
from pygments.lexers import get_lexer_by_name
from pygments.formatters import HtmlFormatter, Terminal256Formatter
lexer = get_lexer_by_name("sql", stripall=True)
formatter = Terminal256Formatter(style='vim')
apikey='SJQP663mcrWeECAL_tBg7ec8Q-iVUekB6lvEPFv6qIBZ'
instancecrn=':v1:bluemix:public:sql-query:us-south:a/852994cdd8f44a249b25b2584d895452:3ca31746-86bf-4b4f-9cbf-593c44dba4db::'
targeturl='cos://jp-tok/firedetect/'

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("ibmcloudsqlquery:///?Api Key=SJQP663mcrWeECAL_tBg7ec8Q-iVUekB6lvEPFv6qIBZ CRN=crn:v1:bluemix:public:sql-query:us-south:a/852994cdd8f44a249b25b2584d895452:3ca31746-86bf-4b4f-9cbf-593c44dba4db:: Client Id=myOAuthClientId&OAuth Client Secret=myOAuthClientSecret&InitiateOAuth=GETANDREFRESH&OAuthSettingsLocation=/PATH/TO/OAuthSettings.txt")
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# <ipython-input-25-b15e878de893> in <module>()
# ----> 1 engine = create_engine("ibmcloudsqlquery:///?Api Key=SJQP663mcrWeECAL_tBg7ec8Q-iVUekB6lvEPFv6qIBZ CRN=crn:v1:bluemix:public:sql-query:us-south:a/852994cdd8f44a249b25b2584d895452:3ca31746-86bf-4b4f-9cbf-593c44dba4db:: Client Id=myOAuthClientId&OAuth Client Secret=myOAuthClientSecret&InitiateOAuth=GETANDREFRESH&OAuthSettingsLocation=/PATH/TO/OAuthSettings.txt")
#
# <string> in create_engine(url, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ...

# %%
import ibm_db
conn = ibm_db.connect("database","username","password")

# %%
import ibm_db
ibm_db.connect("DATABASE=name;HOSTNAME=host;PORT=60000;PROTOCOL=TCPIP;UID=username;
                PWD=password;", "", "")

# %%
import ibm_db
conn = ibm_db.connect("database","username","password")
stmt = ibm_db.exec_immediate(conn, "UPDATE employee SET bonus = '1000' WHERE job = 'MANAGER'")
print "Number of affected rows: ", ibm_db.num_rows(stmt)

# %%
import ibm_db
conn = ibm_db.connect("database","username","password")
if conn:
    sql = "SELECT XMLSERIALIZE(XMLQUERY('for $i in $t/address where $i/city = \"Olathe\" return <zip>{$i/zip/text()}</zip>' passing c.xmlcol as \"t\") AS CLOB(32k)) FROM xml_test c WHERE id = 1"
    stmt = ibm_db.exec_immediate(conn, sql)
    result = ibm_db.fetch_both(stmt)
    while( result ):
        print "Result from XMLSerialize and XMLQuery:", result[0]
        result = ibm_db.fetch_both(stmt)
